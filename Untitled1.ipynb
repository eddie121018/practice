# %%
from bs4 import BeautifulSoup
import requests 
res = requests.get("https://www.hotelscombined.com.tw/Hotel/Search?fileName=Hotel_Monterey_Grasmere_Osaka&destination=place:Osaka&radius=0km&checkin=2017-11-24&checkout=2017-11-30&Rooms=1&adults_1=1&returnPath=%2FHotels%2FSearch%3Fdestination%3Dplace%3AOsaka%26radius%3D0km%26checkin%3D2017-11-24%26checkout%3D2017-11-30%26Rooms%3D1%26adults_1%3D1%26pageSize%3D15%26pageIndex%3D0%26sort%3DPopularity-desc%26showSoldOut%3Dfalse%26scroll%3D0%26HotelID%3D%26mapState%3Dexpanded%253D0%26isNewSRIDesignTarget%3Dtrue")
soup = BeautifulSoup(res.text, "lxml")
for i in soup.select('html'):
    print i
# Out:
# <html lang="zh" xml:lang="zh" xmlns="http://www.w3.org/1999/xhtml" xmlns:og="http://ogp.me/ns#" xmlns:v="urn:schemas-microsoft-com:vml">
# <head>
# <script>
# 			if (window.location.hash && window.location.hash === '#_=_') {
# 				window.location.hash = '';
# 			}
# 		</script>
# <!-- New Relic Header -->
# <link href="https://cdn.datahc.com/Styles/StyleSheet.ashx?key=JQueryUiMain&amp;cdn=1.0.2017.317002-C16ed9d1a7231e662392a6f589e371985bb1bf941" rel="stylesheet" type="text/css"/>
# <link href="https://cdn.datahc.com/Styles/StyleSheet.ashx?key=Main&amp;cdn=1.0.2017.317002-C16ed9d1a7231e662392a6f589e371985bb1bf941" rel="stylesheet" type="text/css"/>
# <title>全球100萬間飯店、住宿、民宿比價超值優惠 - HotelsCombined</title>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="HotelsCombined.com.tw,台北住宿,台中住宿,高雄住宿,大阪住宿,京都住宿,東京住宿" name="keywords"/>
# ...
